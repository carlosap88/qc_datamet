# %%
from qc_datamet.pipeline.pipeline_state import PipelineState

state = PipelineState()

state.start()
state.start_stage("stage01_discovery")
state.add_discovered_file("data/raw/excel/SPIM_2025.xlsx")
state.set_statistic("files_found", 1)
state.complete_stage("stage01_discovery")
state.finish()

state.save("data/staging/checkpoints/pipeline_state.json")

print(state.to_dict())
